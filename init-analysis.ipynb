# %% [markdown]
# ## What effect does a Airbnb host’s bio metadata have on it’s frequency of their rentals being booked?

# %%
import csv
import pandas as pd
import numpy as np

import seaborn as sns

# %%
# import data
calendar_all = pd.read_csv('./data/calendar.csv')
listings_all = pd.read_csv('./data/listings.csv')

# reviews = pd.read_csv('./data/reviews.csv')

# %%
# do a bit of cleaning

# remove cols that only contain (1) unique elem
listings = listings_all
for col in listings_all.columns:
    if len(listings_all[col].unique()) == 1:
        listings = listings.drop(col,axis=1)

# %%
listings.head()

list(listings.columns.values)
# Out:
# ['id',
#  'listing_url',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'smart_location',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
# ...

# %%
host_data = listings[['host_id',
 'host_url',
 'host_name',
 'host_since',
 'host_location',
 'host_about',
 'host_response_time',
 'host_response_rate',
 'host_acceptance_rate',
 'host_is_superhost',
 'host_thumbnail_url',
 'host_picture_url',
 'host_neighbourhood',
 'host_listings_count',
 'host_total_listings_count',
 'host_verifications',
 'host_has_profile_pic',
 'host_identity_verified']]

host_data.head()
# Out:
#     host_id                                    host_url host_name  host_since  \
# 0    956883    https://www.airbnb.com/users/show/956883     Maija  2011-08-11
# 1   5177328   https://www.airbnb.com/users/show/5177328    Andrea  2013-02-21
# 2  16708587  https://www.airbnb.com/users/show/16708587      Jill  2014-06-12
# 3   9851441   https://www.airbnb.com/users/show/9851441     Emily  2013-11-06
# 4   1452570   https://www.airbnb.com/users/show/1452570     Emily  2011-11-29
#
#                         host_location  \
# 0  Seattle, Washington, United States
# 1  Seattle, Washington, United States
# 2  Seattle, Washington, United States
# 3  Seattle, Washington, United States
# 4  Seattle, Washington, United States
#
#                                           host_about  host_response_time  \
# 0  I am an artist, interior designer, and run a s...  within a few hours
# 1  Living east coast/left coast/overseas.  Time i...      within an hour
# ...

# %%
# number of about sections that we have data for: 3817 - 858 = 2959
host_data['host_about'].count()

# only 7 hosts do not have a profile picture
host_data[host_data.host_has_profile_pic == 'f']

host_data['host_about']
# Out:
# 0       I am an artist, interior designer, and run a s...
# 1       Living east coast/left coast/overseas.  Time i...
# 2       i love living in Seattle.  i grew up in the mi...
# 3                                                     NaN
# 4       Hi, I live in Seattle, Washington but I'm orig...
# 5       I've been fortunate to have had many life expe...
# 6       We have lived in the the Queen Anne neighborho...
# 7       I am a carpenter at heart , I love music , I p...
# 8       I'm a 35 year old professional from Seattle, W...
# 9       Living east coast/left coast/overseas.  Time i...
# 10      Eileen and Ray were born in Seattle just three...
# 11      My name is Nadia, and I am a native of Seattle...
# 12      We both grew up on Queen Anne Hill, then later...
# 13      Hi, my name is Ellie.  I’m a widow.  My husban...
# 14      Originally from Southern California, my husban...
# 15      I'm from Seattle.  I am a designer, inventor a...
# ...

# %%
len(host_data.host_id.unique())
# number of unique hosts: 2751
# Out:
# 2751

# %%
listings[listings.require_guest_profile_picture == 't']
# Out:
#            id                           listing_url  \
# 1      953595   https://www.airbnb.com/rooms/953595
# 7      856550   https://www.airbnb.com/rooms/856550
# 9     2493658  https://www.airbnb.com/rooms/2493658
# 10     175576   https://www.airbnb.com/rooms/175576
# 27    3200646  https://www.airbnb.com/rooms/3200646
# 30    2481869  https://www.airbnb.com/rooms/2481869
# 41    2715623  https://www.airbnb.com/rooms/2715623
# 61    2746782  https://www.airbnb.com/rooms/2746782
# 63     762029   https://www.airbnb.com/rooms/762029
# 73    1148517  https://www.airbnb.com/rooms/1148517
# 97    4395578  https://www.airbnb.com/rooms/4395578
# 183    888967   https://www.airbnb.com/rooms/888967
# 187    904057   https://www.airbnb.com/rooms/904057
# 196    843812   https://www.airbnb.com/rooms/843812
# 205    757840   https://www.airbnb.com/rooms/757840
# 212    781474   https://www.airbnb.com/rooms/781474
# 231   5848400  https://www.airbnb.com/rooms/5848400
# ...
